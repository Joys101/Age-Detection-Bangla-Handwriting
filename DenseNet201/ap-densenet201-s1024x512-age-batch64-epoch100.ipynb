# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback

# Set number of threads
tf.config.threading.set_intra_op_parallelism_threads(96)  # Use all logical cores
tf.config.threading.set_inter_op_parallelism_threads(2)   # Experiment with inter-op threads
# Enable XLA JIT compilation
tf.config.optimizer.set_jit(True)
# Out:
# 2024-10-13 07:20:01.004404: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-13 07:20:01.011443: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-13 07:20:01.036607: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-13 07:20:01.112515: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-13 07:20:01.125200: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-13 07:20:01.154448: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-13 07:20:04.506288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#with strategy.scope():
# Load the dataset
data = np.load('/home/showv/BanglaOCR/AP-Model Training/Dataset/AGE_1024_512_Class5.npz') #/home/showv/BanglaOCR/Dataset
X_train, y_train = data['X_train'], data['y_train']
X_test, y_test = data['X_test'], data['y_test']

# Reshape the images (from flat to original size)
X_train = X_train.reshape((-1, 512, 1024, 1)) #.astype(np.float16)  # Grayscale
X_test = X_test.reshape((-1, 512, 1024, 1)) #.astype(np.float16)
    
# Convert grayscale to 3 channels by repeating the single channel
X_train = np.repeat(X_train, 3, axis=-1)
X_test = np.repeat(X_test, 3, axis=-1)

# Normalize pixel values (0-255) to range (0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (9154, 512, 1024, 3)
# y_train shape: (9154, 5)
# X_test shape: (2289, 512, 1024, 3)
# y_test shape: (2289, 5)

# %%
# # !echo $CUDA_VISIBLE_DEVICES
# # !export CUDA_VISIBLE_DEVICES=0,1

# import tensorflow as tf

# # Check if GPU is available
# print(tf.config.list_physical_devices('GPU'))
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# %%
# import tensorflow as tf

# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver()

# # instantiate a distribution strategy
# tf.tpu.experimental.initialize_tpu_system(tpu)
# tpu_strategy = tf.distribute.TPUStrategy(tpu)

# # Create a strategy for distributed training
# strategy = tf.distribute.MirroredStrategy()

# %%
#with strategy.scope():
#with tpu_strategy.scope():
# Define the base model with ImageNet weights, without the top layers
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(512, 1024, 3))

# Freeze the base model layers
base_model.trainable = False

# Add custom layers on top of the base model
inputs = Input(shape=(512, 1024, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)  # Global average pooling layer
x = Dense(128, activation='relu')(x)  # Custom dense layer
outputs = Dense(5, activation='softmax')(x)  # Output layer for 2 classes

# Create the final model
model = Model(inputs, outputs)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 512, 1024, 3)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet201 (Functional)        │ (None, 16, 32, 1920)   │    18,321,984 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1920)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       245,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,568,517 (70.83 MB)
#  Trainable params: 246,533 (963.02 KB)
#  Non-trainable params: 18,321,984 (69.89 MB)

# %%
class SaveHistory(Callback):
    def __init__(self, filename):
        super(SaveHistory, self).__init__()
        self.filename = filename

    def on_epoch_end(self, epoch, logs=None):
        # If the file exists, load the previous history
        try:
            with open(self.filename, 'r') as f:
                history = json.load(f)
        except FileNotFoundError:
            history = {}
        
        # Append new logs to the history
        for key, value in logs.items():
            if key not in history:
                history[key] = []
            history[key].append(value)
        
        # Save the updated history to file
        with open(self.filename, 'w') as f:
            json.dump(history, f)


# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
checkpoint = ModelCheckpoint('AP-DenseNet201_1024Age_checkpoint.keras', monitor='val_loss', save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
history_callback = SaveHistory('AP-DenseNet201_1024Age_history.json')

# %%
# Train the model
history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=100,  # You can increase epochs based on performance
                    batch_size=64,
                    callbacks=[early_stopping, checkpoint, history_callback])
# Out:
# Epoch 1/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1719s 12s/step - accuracy: 0.2774 - loss: 1.6000 - val_accuracy: 0.3801 - val_loss: 1.4515
# Epoch 2/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1556s 11s/step - accuracy: 0.3876 - loss: 1.4291 - val_accuracy: 0.4268 - val_loss: 1.3676
# Epoch 3/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1571s 11s/step - accuracy: 0.4409 - loss: 1.3509 - val_accuracy: 0.4561 - val_loss: 1.3234
# Epoch 4/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1498s 10s/step - accuracy: 0.4667 - loss: 1.3180 - val_accuracy: 0.4849 - val_loss: 1.2914
# Epoch 5/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1542s 11s/step - accuracy: 0.4650 - loss: 1.2978 - val_accuracy: 0.4644 - val_loss: 1.2774
# Epoch 6/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1494s 10s/step - accuracy: 0.4839 - loss: 1.2594 - val_accuracy: 0.4854 - val_loss: 1.2560
# Epoch 7/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1507s 10s/step - accuracy: 0.4864 - loss: 1.2455 - val_accuracy: 0.4827 - val_loss: 1.2452
# Epoch 8/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1576s 11s/step - accuracy: 0.4874 - loss: 1.2347 - val_accuracy: 0.4858 - val_loss: 1.2358
# Epoch 9/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1525s 11s/step - accuracy: 0.4973 - loss: 1.2244 - val_accuracy: 0.5076 - val_loss: 1.2145
# Epoch 10/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1487s 10s/step - accuracy: 0.5079 - loss: 1.2145 - val_accuracy: 0.4993 - val_loss: 1.2134
# Epoch 11/100
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1572s 11s/step - accuracy: 0.5100 - loss: 1.1952 - val_accuracy: 0.5094 - val_loss: 1.2008
# Epoch 12/100
#  11/144 ━━━━━━━━━━━━━━━━━━━━ 18:23 8s/step - accuracy: 0.5039 - loss: 1.1873

# %%
#Load the saved model and history
from tensorflow.keras.models import load_model

model = load_model('AP-DenseNet201_1024Age_checkpoint.keras')
with open('AP-DenseNet201_1024Age_history.json', 'r') as f:
    history = json.load(f)

history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=90,  # You can increase epochs based on performance
                    batch_size=64,
                    callbacks=[early_stopping, checkpoint, history_callback])
# Out:
# Epoch 1/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1772s 12s/step - accuracy: 0.4993 - loss: 1.2019 - val_accuracy: 0.5155 - val_loss: 1.1943
# Epoch 2/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1726s 12s/step - accuracy: 0.5093 - loss: 1.1801 - val_accuracy: 0.5076 - val_loss: 1.1900
# Epoch 3/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1733s 12s/step - accuracy: 0.5151 - loss: 1.1788 - val_accuracy: 0.5190 - val_loss: 1.1860
# Epoch 4/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1571s 11s/step - accuracy: 0.5216 - loss: 1.1656 - val_accuracy: 0.4806 - val_loss: 1.2130
# Epoch 5/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1542s 11s/step - accuracy: 0.5142 - loss: 1.1672 - val_accuracy: 0.5159 - val_loss: 1.1770
# Epoch 6/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1544s 11s/step - accuracy: 0.5155 - loss: 1.1688 - val_accuracy: 0.5229 - val_loss: 1.1718
# Epoch 7/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1532s 11s/step - accuracy: 0.5159 - loss: 1.1603 - val_accuracy: 0.5133 - val_loss: 1.1669
# Epoch 8/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1541s 11s/step - accuracy: 0.5218 - loss: 1.1408 - val_accuracy: 0.5125 - val_loss: 1.1681
# Epoch 9/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1499s 10s/step - accuracy: 0.5210 - loss: 1.1505 - val_accuracy: 0.5304 - val_loss: 1.1489
# Epoch 10/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1489s 10s/step - accuracy: 0.5367 - loss: 1.1362 - val_accuracy: 0.5352 - val_loss: 1.1438
# Epoch 11/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1599s 11s/step - accuracy: 0.5410 - loss: 1.1164 - val_accuracy: 0.5308 - val_loss: 1.1441
# Epoch 12/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1498s 10s/step - accuracy: 0.5464 - loss: 1.1221 - val_accuracy: 0.5400 - val_loss: 1.1356
# Epoch 13/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1510s 10s/step - accuracy: 0.5529 - loss: 1.1040 - val_accuracy: 0.5369 - val_loss: 1.1360
# Epoch 14/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1552s 11s/step - accuracy: 0.5409 - loss: 1.1118 - val_accuracy: 0.5378 - val_loss: 1.1317
# Epoch 15/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1478s 10s/step - accuracy: 0.5477 - loss: 1.1019 - val_accuracy: 0.5378 - val_loss: 1.1309
# Epoch 16/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1514s 11s/step - accuracy: 0.5477 - loss: 1.1091 - val_accuracy: 0.5395 - val_loss: 1.1262
# Epoch 17/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1529s 11s/step - accuracy: 0.5462 - loss: 1.1058 - val_accuracy: 0.5417 - val_loss: 1.1208
# Epoch 18/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1540s 11s/step - accuracy: 0.5494 - loss: 1.0926 - val_accuracy: 0.5378 - val_loss: 1.1262
# Epoch 19/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1535s 11s/step - accuracy: 0.5550 - loss: 1.0875 - val_accuracy: 0.5535 - val_loss: 1.1105
# Epoch 20/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1469s 10s/step - accuracy: 0.5611 - loss: 1.0797 - val_accuracy: 0.5491 - val_loss: 1.1082
# Epoch 21/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1515s 11s/step - accuracy: 0.5624 - loss: 1.0683 - val_accuracy: 0.5426 - val_loss: 1.1098
# Epoch 22/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1593s 11s/step - accuracy: 0.5709 - loss: 1.0774 - val_accuracy: 0.5365 - val_loss: 1.1096
# Epoch 23/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1655s 12s/step - accuracy: 0.5661 - loss: 1.0638 - val_accuracy: 0.5505 - val_loss: 1.1020
# Epoch 24/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1540s 11s/step - accuracy: 0.5801 - loss: 1.0541 - val_accuracy: 0.5548 - val_loss: 1.0991
# Epoch 25/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1593s 11s/step - accuracy: 0.5541 - loss: 1.0817 - val_accuracy: 0.5483 - val_loss: 1.1028
# Epoch 26/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1678s 12s/step - accuracy: 0.5698 - loss: 1.0646 - val_accuracy: 0.5535 - val_loss: 1.0937
# Epoch 27/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1579s 11s/step - accuracy: 0.5705 - loss: 1.0520 - val_accuracy: 0.5513 - val_loss: 1.0926
# Epoch 28/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1571s 11s/step - accuracy: 0.5751 - loss: 1.0470 - val_accuracy: 0.5496 - val_loss: 1.0937
# Epoch 29/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1588s 11s/step - accuracy: 0.5674 - loss: 1.0521 - val_accuracy: 0.5553 - val_loss: 1.0866
# Epoch 30/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1583s 11s/step - accuracy: 0.5836 - loss: 1.0401 - val_accuracy: 0.5474 - val_loss: 1.0949
# Epoch 31/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1623s 11s/step - accuracy: 0.5774 - loss: 1.0506 - val_accuracy: 0.5583 - val_loss: 1.0863
# Epoch 32/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1545s 11s/step - accuracy: 0.5792 - loss: 1.0396 - val_accuracy: 0.5588 - val_loss: 1.0885
# Epoch 33/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1549s 11s/step - accuracy: 0.5847 - loss: 1.0308 - val_accuracy: 0.5557 - val_loss: 1.0766
# Epoch 34/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1558s 11s/step - accuracy: 0.5801 - loss: 1.0365 - val_accuracy: 0.5618 - val_loss: 1.0736
# Epoch 35/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1545s 11s/step - accuracy: 0.5834 - loss: 1.0328 - val_accuracy: 0.5522 - val_loss: 1.0824
# Epoch 36/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1512s 11s/step - accuracy: 0.5965 - loss: 1.0216 - val_accuracy: 0.5570 - val_loss: 1.0796
# Epoch 37/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1558s 11s/step - accuracy: 0.5858 - loss: 1.0120 - val_accuracy: 0.5627 - val_loss: 1.0731
# Epoch 38/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1582s 11s/step - accuracy: 0.5956 - loss: 1.0149 - val_accuracy: 0.5640 - val_loss: 1.0724
# Epoch 39/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1558s 11s/step - accuracy: 0.5879 - loss: 1.0149 - val_accuracy: 0.5636 - val_loss: 1.0615
# Epoch 40/90
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1542s 11s/step - accuracy: 0.6023 - loss: 1.0109 - val_accuracy: 0.5662 - val_loss: 1.0661
# Epoch 41/90
#  60/144 ━━━━━━━━━━━━━━━━━━━━ 11:43 8s/step - accuracy: 0.5700 - loss: 1.0296

# %%
#Load the saved model and history
from tensorflow.keras.models import load_model

model = load_model('AP-DenseNet201_1024Age_checkpoint.keras')
with open('AP-DenseNet201_1024Age_history.json', 'r') as f:
    history = json.load(f)

history = model.fit(X_train, y_train,
                    validation_data=(X_test, y_test),
                    epochs=50,  # You can increase epochs based on performance
                    batch_size=64,
                    callbacks=[early_stopping, checkpoint, history_callback])
# Out:
# Epoch 1/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1753s 12s/step - accuracy: 0.6039 - loss: 1.0075 - val_accuracy: 0.5688 - val_loss: 1.0643
# Epoch 2/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1714s 12s/step - accuracy: 0.6060 - loss: 0.9997 - val_accuracy: 0.5775 - val_loss: 1.0585
# Epoch 3/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1708s 12s/step - accuracy: 0.5980 - loss: 1.0067 - val_accuracy: 0.5579 - val_loss: 1.0731
# Epoch 4/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1687s 12s/step - accuracy: 0.6041 - loss: 1.0047 - val_accuracy: 0.5745 - val_loss: 1.0560
# Epoch 5/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1664s 12s/step - accuracy: 0.5977 - loss: 1.0072 - val_accuracy: 0.5749 - val_loss: 1.0547
# Epoch 6/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1595s 11s/step - accuracy: 0.6043 - loss: 0.9969 - val_accuracy: 0.5714 - val_loss: 1.0525
# Epoch 7/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1582s 11s/step - accuracy: 0.6017 - loss: 0.9991 - val_accuracy: 0.5679 - val_loss: 1.0593
# Epoch 8/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1649s 11s/step - accuracy: 0.6033 - loss: 0.9992 - val_accuracy: 0.5662 - val_loss: 1.0529
# Epoch 9/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1634s 11s/step - accuracy: 0.5979 - loss: 1.0002 - val_accuracy: 0.5653 - val_loss: 1.0573
# Epoch 10/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1625s 11s/step - accuracy: 0.6070 - loss: 0.9860 - val_accuracy: 0.5653 - val_loss: 1.0517
# Epoch 11/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1664s 12s/step - accuracy: 0.6026 - loss: 0.9869 - val_accuracy: 0.5649 - val_loss: 1.0517
# Epoch 12/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1690s 12s/step - accuracy: 0.6094 - loss: 0.9779 - val_accuracy: 0.5723 - val_loss: 1.0454
# Epoch 13/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1620s 11s/step - accuracy: 0.6196 - loss: 0.9618 - val_accuracy: 0.5719 - val_loss: 1.0471
# Epoch 14/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1612s 11s/step - accuracy: 0.6196 - loss: 0.9751 - val_accuracy: 0.5732 - val_loss: 1.0403
# Epoch 15/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1621s 11s/step - accuracy: 0.6084 - loss: 0.9830 - val_accuracy: 0.5723 - val_loss: 1.0435
# Epoch 16/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1641s 11s/step - accuracy: 0.6098 - loss: 0.9811 - val_accuracy: 0.5710 - val_loss: 1.0383
# Epoch 17/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1630s 11s/step - accuracy: 0.6221 - loss: 0.9626 - val_accuracy: 0.5767 - val_loss: 1.0421
# Epoch 18/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1683s 12s/step - accuracy: 0.6180 - loss: 0.9602 - val_accuracy: 0.5745 - val_loss: 1.0400
# Epoch 19/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1675s 12s/step - accuracy: 0.6229 - loss: 0.9514 - val_accuracy: 0.5797 - val_loss: 1.0332
# Epoch 20/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1632s 11s/step - accuracy: 0.6276 - loss: 0.9574 - val_accuracy: 0.5740 - val_loss: 1.0314
# Epoch 21/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1692s 12s/step - accuracy: 0.6170 - loss: 0.9641 - val_accuracy: 0.5740 - val_loss: 1.0324
# Epoch 22/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1632s 11s/step - accuracy: 0.6270 - loss: 0.9555 - val_accuracy: 0.5679 - val_loss: 1.0501
# Epoch 23/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1644s 11s/step - accuracy: 0.6231 - loss: 0.9484 - val_accuracy: 0.5706 - val_loss: 1.0432
# Epoch 24/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1655s 12s/step - accuracy: 0.6190 - loss: 0.9552 - val_accuracy: 0.5679 - val_loss: 1.0375
# Epoch 25/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1639s 11s/step - accuracy: 0.6305 - loss: 0.9460 - val_accuracy: 0.5692 - val_loss: 1.0342
# Epoch 26/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1642s 11s/step - accuracy: 0.6275 - loss: 0.9492 - val_accuracy: 0.5806 - val_loss: 1.0263
# Epoch 27/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1644s 11s/step - accuracy: 0.6263 - loss: 0.9408 - val_accuracy: 0.5723 - val_loss: 1.0317
# Epoch 28/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1631s 11s/step - accuracy: 0.6331 - loss: 0.9227 - val_accuracy: 0.5824 - val_loss: 1.0243
# Epoch 29/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1557s 11s/step - accuracy: 0.6301 - loss: 0.9377 - val_accuracy: 0.5819 - val_loss: 1.0346
# Epoch 30/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1638s 11s/step - accuracy: 0.6432 - loss: 0.9306 - val_accuracy: 0.5797 - val_loss: 1.0206
# Epoch 31/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1594s 11s/step - accuracy: 0.6314 - loss: 0.9320 - val_accuracy: 0.5754 - val_loss: 1.0260
# Epoch 32/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1625s 11s/step - accuracy: 0.6336 - loss: 0.9310 - val_accuracy: 0.5872 - val_loss: 1.0277
# Epoch 33/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1620s 11s/step - accuracy: 0.6264 - loss: 0.9480 - val_accuracy: 0.5723 - val_loss: 1.0223
# Epoch 34/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1660s 12s/step - accuracy: 0.6403 - loss: 0.9227 - val_accuracy: 0.5898 - val_loss: 1.0142
# Epoch 35/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1820s 12s/step - accuracy: 0.6302 - loss: 0.9348 - val_accuracy: 0.5880 - val_loss: 1.0211
# Epoch 36/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1625s 11s/step - accuracy: 0.6409 - loss: 0.9198 - val_accuracy: 0.5819 - val_loss: 1.0112
# Epoch 37/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1614s 11s/step - accuracy: 0.6280 - loss: 0.9306 - val_accuracy: 0.5797 - val_loss: 1.0226
# Epoch 38/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1703s 12s/step - accuracy: 0.6389 - loss: 0.9171 - val_accuracy: 0.5824 - val_loss: 1.0165
# Epoch 39/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1621s 11s/step - accuracy: 0.6497 - loss: 0.9057 - val_accuracy: 0.5858 - val_loss: 1.0136
# Epoch 40/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1617s 11s/step - accuracy: 0.6467 - loss: 0.9048 - val_accuracy: 0.5815 - val_loss: 1.0109
# Epoch 41/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1647s 11s/step - accuracy: 0.6386 - loss: 0.9144 - val_accuracy: 0.5858 - val_loss: 1.0024
# Epoch 42/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1635s 11s/step - accuracy: 0.6460 - loss: 0.9063 - val_accuracy: 0.5915 - val_loss: 1.0036
# Epoch 43/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1609s 11s/step - accuracy: 0.6476 - loss: 0.9033 - val_accuracy: 0.5876 - val_loss: 1.0112
# Epoch 44/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1605s 11s/step - accuracy: 0.6441 - loss: 0.9199 - val_accuracy: 0.5885 - val_loss: 1.0067
# Epoch 45/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1605s 11s/step - accuracy: 0.6464 - loss: 0.9032 - val_accuracy: 0.5858 - val_loss: 1.0129
# Epoch 46/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1608s 11s/step - accuracy: 0.6405 - loss: 0.8995 - val_accuracy: 0.5815 - val_loss: 1.0100
# Epoch 47/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1615s 11s/step - accuracy: 0.6465 - loss: 0.8986 - val_accuracy: 0.5885 - val_loss: 1.0034
# Epoch 48/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1581s 11s/step - accuracy: 0.6516 - loss: 0.8958 - val_accuracy: 0.5858 - val_loss: 1.0172
# Epoch 49/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1611s 11s/step - accuracy: 0.6532 - loss: 0.8942 - val_accuracy: 0.5837 - val_loss: 1.0085
# Epoch 50/50
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 1633s 11s/step - accuracy: 0.6560 - loss: 0.8908 - val_accuracy: 0.6016 - val_loss: 0.9906

# %%
# Save the model in .keras format
model.save('AP-DenseNet201_Model_1024Age_Trained.keras')

# Evaluate on the test set
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 310s 4s/step - accuracy: 0.5966 - loss: 0.9954
# Test accuracy: 60.16%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import tensorflow.keras.optimizers as optimizers
import matplotlib.pyplot as plt

# Get the default learning rate for the Adam optimizer
d_learning_rate = optimizers.Adam().get_config()['learning_rate']

# Predictions
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)

# Metrics calculation
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
recall = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)

# Additional information
print("Number of Epochs:", len(history.history['accuracy']))
print("Size of Image:", X_train.shape[1:])
print("Learning Rate: ",d_learning_rate)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 352s 5s/step
# Accuracy: 0.601572739187418
# Precision: 0.595898975320656
# Recall: 0.6052102881380492
# F1 Score: 0.5978164227950117
# Number of Epochs: 50
# Size of Image: (512, 1024, 3)
# Learning Rate:  0.0010000000474974513

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Evaluate the model and get predictions
y_pred = model.predict(X_test)

# Convert the predictions from one-hot encoded to class labels
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

# Generate the confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# Plot the confusion matrix
labels = ['A14-16', 'A8-10', 'A11-13', 'A4-7', 'A17-21']  # Adjust according to your labels

plt.figure(figsize=(16, 16))
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues, values_format='d')

# Add title and axis labels
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Show the plot
plt.show()
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 322s 4s/step

# %%
# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
